# %% [markdown]
# ## 1. Setup main imports

# %%
# Torch imports
import torch
import torchvision
import torchvision.models as models
import torch.nn as nn
from torchvision import transforms, datasets
from torchinfo import summary
import numpy as np
from PIL import Image
from pathlib import Path
import os
import random
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from typing import List, Dict, Tuple
from tqdm.notebook import tqdm
import sys

print(os.getcwd())
# Out:
# /home/felipe/IA/Food101/model-training

# %%
# Setting device agnostic code
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## 2. Setting up data

# %% [markdown]
# ### Linux based file system

# %%
import shutil

# Define the directories
base_dir = 'data/food-101/images'
train_dir = 'train_images'
test_dir = 'test_images'
meta_dir = 'data/food-101/meta'

# Define new directories
new_dir = 'data/new-food-101'
images_dir = 'data/new-food-101/images'
train_dir = f'{images_dir}/train'
test_dir = f'{images_dir}/test'
meta_dir = 'data/new-food-101/meta'

# Create new directories
os.makedirs(new_dir, exist_ok=True)
os.makedirs(images_dir, exist_ok=True)
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)
os.makedirs(meta_dir, exist_ok=True)

# Moving all meta files to new directory
# Get all elements from meta directory
meta_files = os.listdir(Path("data/food-101/meta"))

# Move all meta files to new directory
for file in meta_files:
    shutil.move(os.path.join("data/food-101/meta", file), os.path.join(meta_dir, file))


# Move all images to new directory
# Get all classes from the train directory
classes = os.listdir(Path("data/food-101/images"))

# Create new directories for each class
for class_name in classes:
    os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(test_dir, class_name), exist_ok=True)

# Move train images to new directory
# Get all test images from 'train.txt'
with open("data/new-food-101/meta/train.txt", "r") as file:
    # Get all train images
    train_images = file.readlines()
    print(train_images[0])
    
     # Add .jpg extension to all images
    new_train_images = [f'{image.strip("\n")}.jpg' for image in train_images]

    # Move all train images to new directory
    for image in new_train_images:
        class_name, image_name = image.split("/")
        shutil.move(os.path.join("data/food-101/images", class_name, image_name), os.path.join(train_dir, class_name, image_name))


# Move test images to new directory
# Get all test images from 'test.txt'
with open("data/new-food-101/meta/test.txt", "r") as file:
    # Get all test images
    test_images = file.readlines()
    
    # Add .jpg extension to all images
    new_test_images = [f'{image.strip("\n")}.jpg' for image in test_images]

    # Move all test images to new directory
    for image in new_test_images:
        class_name, image_name = image.split("/")
        shutil.move(os.path.join("data/food-101/images", class_name, image_name), os.path.join(test_dir, class_name, image_name))


print("Data has been successfully moved to new directory!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[57], line 25
#      21 os.makedirs(meta_dir, exist_ok=True)
#      23 # Moving all meta files to new directory
#      24 # Get all elements from meta directory
# ---> 25 meta_files = os.listdir(Path("data/food-101/meta"))
#      27 # Move all meta files to new directory
#      28 for file in meta_files:
#
# FileNotFoundError: [WinError 3] O sistema não pode encontrar o caminho especificado: 'data\\food-101\\meta'

# %% [markdown]
# ### Windows Based file system

# %%
import shutil
from pathlib import Path
import os

# Define the directories using Path for better cross-platform compatibility
base_dir = Path('data/food-101/images')

# Base for new directories
train_dir = Path('train_images')
test_dir = Path('test_images')

# Getting meta from the old
meta_dir = Path('data/food-101/meta')

# Define new directories
new_dir = Path('data/new-food-101')
images_dir = new_dir / 'images'
train_dir = images_dir / 'train'
test_dir = images_dir / 'test'
new_meta_dir = new_dir / 'meta'

# Create new directories
os.makedirs(new_dir, exist_ok=True)
os.makedirs(images_dir, exist_ok=True)
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)
os.makedirs(new_meta_dir, exist_ok=True)

# Moving all meta files to new directory
# Get all elements from meta directory
meta_files = list(meta_dir.glob('*'))

# Move all meta files to new directory
for file in meta_files:
    shutil.move(str(file), str(meta_dir / file.name))

# Move all images to new directory
# Get all classes from the base directory
classes = [d.name for d in base_dir.iterdir() if d.is_dir()]

# Create new directories for each class
for class_name in classes:
    os.makedirs(train_dir / class_name, exist_ok=True)
    os.makedirs(test_dir / class_name, exist_ok=True)

# Function to move images based on a list from a text file
def move_images(source_base_dir, dest_dir, meta_file):
    with open(meta_file, "r") as file:
        images = [f"{image.strip()}.jpg" for image in file.readlines()]

        for image in images:
            class_name, image_name = image.split("/")
            source_path = source_base_dir / class_name / image_name
            dest_path = dest_dir / class_name / image_name
            os.makedirs(dest_dir / class_name, exist_ok=True)
            shutil.move(str(source_path), str(dest_path))

# Move train images to new directory
move_images(base_dir, train_dir, meta_dir / 'train.txt')

# Move test images to new directory
move_images(base_dir, test_dir, meta_dir / 'test.txt')

print("Data has been successfully moved to new directory!")
# Out:
# Data has been successfully moved to new directory!

# %%
# Once the images have been moved, we can delete the old directories
# Delete old directories
shutil.rmtree("data/food-101")

# Renaming the new directories
os.rename("data/new-food-101", "data/food-101")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Once the images have been moved, we can delete the old directories
#       2 # Delete old directories
# ----> 3 shutil.rmtree("data/food-101")
#       5 # Renaming the new directories
#       6 os.rename("data/new-food-101", "data/food-101")
#
# NameError: name 'shutil' is not defined

# %%
# Using pathlib to get the image paths
DATAPATH = Path('data')
food101 = DATAPATH/'food-101'/'images'
print(food101)
# Out:
# data/food-101/images

# %%
# Walking through directories

for dirpath, dirnames, filenames in os.walk(food101):
    print(f'Found directory: {dirpath}')
    print(f'Directory has {len(dirnames)} directories and {len(filenames)} files')
    print('---------------------------------------------')
# Out:
# Found directory: data/food-101/images
# Directory has 2 directories and 0 files
# ---------------------------------------------
# Found directory: data/food-101/images/train
# Directory has 101 directories and 0 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/croque_madame
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/cheese_plate
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/samosa
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/huevos_rancheros
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/waffles
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/fish_and_chips
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/poutine
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/gyoza
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/oysters
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/sashimi
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/sushi
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/frozen_yogurt
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/cannoli
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/shrimp_and_grits
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/bread_pudding
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/spring_rolls
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/lobster_bisque
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/chocolate_cake
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/gnocchi
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/spaghetti_carbonara
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/lobster_roll_sandwich
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/breakfast_burrito
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/apple_pie
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/prime_rib
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/fried_rice
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/onion_rings
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/beef_tartare
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/mussels
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/caesar_salad
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/deviled_eggs
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/paella
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/pulled_pork_sandwich
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/baklava
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/guacamole
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/tiramisu
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/pizza
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/panna_cotta
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/hot_dog
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/cheesecake
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/edamame
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/hummus
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/grilled_cheese_sandwich
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/macaroni_and_cheese
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/chicken_quesadilla
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/scallops
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/chicken_wings
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/crab_cakes
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/greek_salad
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/caprese_salad
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/risotto
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/carrot_cake
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/pork_chop
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/bibimbap
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/beef_carpaccio
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/filet_mignon
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/chicken_curry
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/ramen
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/pho
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/macarons
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/pancakes
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/fried_calamari
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/pad_thai
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/spaghetti_bolognese
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/omelette
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/bruschetta
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/churros
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/tacos
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/seaweed_salad
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/takoyaki
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/garlic_bread
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/french_fries
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/steak
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/escargots
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/miso_soup
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/ice_cream
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/chocolate_mousse
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/hamburger
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/strawberry_shortcake
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/falafel
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/creme_brulee
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/eggs_benedict
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/beignets
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/hot_and_sour_soup
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/donuts
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/red_velvet_cake
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/club_sandwich
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/ceviche
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/french_onion_soup
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/foie_gras
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/grilled_salmon
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/cup_cakes
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/baby_back_ribs
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/lasagna
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/dumplings
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/ravioli
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/french_toast
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/tuna_tartare
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/peking_duck
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/beet_salad
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/nachos
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/train/clam_chowder
# Directory has 0 directories and 750 files
# ---------------------------------------------
# Found directory: data/food-101/images/test
# Directory has 101 directories and 0 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/croque_madame
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/cheese_plate
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/samosa
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/huevos_rancheros
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/waffles
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/fish_and_chips
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/poutine
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/gyoza
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/oysters
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/sashimi
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/sushi
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/frozen_yogurt
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/cannoli
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/shrimp_and_grits
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/bread_pudding
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/spring_rolls
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/lobster_bisque
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/chocolate_cake
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/gnocchi
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/spaghetti_carbonara
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/lobster_roll_sandwich
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/breakfast_burrito
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/apple_pie
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/prime_rib
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/fried_rice
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/onion_rings
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/beef_tartare
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/mussels
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/caesar_salad
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/deviled_eggs
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/paella
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/pulled_pork_sandwich
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/baklava
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/guacamole
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/tiramisu
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/pizza
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/panna_cotta
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/hot_dog
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/cheesecake
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/edamame
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/hummus
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/grilled_cheese_sandwich
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/macaroni_and_cheese
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/chicken_quesadilla
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/scallops
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/chicken_wings
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/crab_cakes
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/greek_salad
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/caprese_salad
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/risotto
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/carrot_cake
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/pork_chop
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/bibimbap
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/beef_carpaccio
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/filet_mignon
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/chicken_curry
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/ramen
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/pho
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/macarons
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/pancakes
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/fried_calamari
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/pad_thai
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/spaghetti_bolognese
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/omelette
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/bruschetta
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/churros
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/tacos
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/seaweed_salad
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/takoyaki
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/garlic_bread
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/french_fries
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/steak
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/escargots
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/miso_soup
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/ice_cream
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/chocolate_mousse
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/hamburger
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/strawberry_shortcake
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/falafel
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/creme_brulee
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/eggs_benedict
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/beignets
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/hot_and_sour_soup
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/donuts
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/red_velvet_cake
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/club_sandwich
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/ceviche
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/french_onion_soup
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/foie_gras
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/grilled_salmon
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/cup_cakes
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/baby_back_ribs
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/lasagna
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/dumplings
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/ravioli
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/french_toast
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/tuna_tartare
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/peking_duck
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/beet_salad
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/nachos
# Directory has 0 directories and 250 files
# ---------------------------------------------
# Found directory: data/food-101/images/test/clam_chowder
# Directory has 0 directories and 250 files
# ---------------------------------------------

# %%
# Setup train and testing directories
train_dir = Path('data/food-101/images/train')

test_dir = Path("data/food-101/images/test")

train_dir, test_dir
# Out:
# (PosixPath('data/food-101/images/train'),
#  PosixPath('data/food-101/images/test'))

# %% [markdown]
# ### Visualizing a random image

# %%
# Getting all image paths
train_images = list(train_dir.rglob('*/*.jpg'))

# Pick a random image
random_image = random.choice(train_images)

# Opening image
img = Image.open(random_image)

# Getting class name
class_name = random_image.parent.name

# Plotting image and metadata
print(f'Class Name: {class_name}')
img
# Out:
# Class Name: breakfast_burrito
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=382x512>

# %%
# Turning the image into a numpy array
img_array = np.array(img)

# Plotting with matplotlib
plt.imshow(img_array)
plt.axis('off')
plt.title(f"Image class: {class_name} | Image shape: {img_array.shape} -> (H, W, C)")
# Out:
# Text(0.5, 1.0, 'Image class: breakfast_burrito | Image shape: (512, 382, 3) -> (H, W, C)')

# %% [markdown]
# ## 3. Transform the data

# %%
# Data augmentation for training
train_transform = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       torchvision.transforms.AutoAugment(torchvision.transforms.AutoAugmentPolicy.IMAGENET),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])
# Data augmentation for testing
test_transform = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

# %%
# Testing the transforms
print("Image before transformation:")
print(f"Image type: {img_array.dtype}")
print(f"Image shape: {img_array.shape} -> (H, W, C)")

transformed_img = test_transform(img)
print("\nImage after transformation:")
print(f"Transformed image type: {transformed_img.dtype}")
print(f"Transformed image shape: {transformed_img.shape} -> (C, H, W)")
# Out:
# Image before transformation:
# Image type: uint8
# Image shape: (512, 382, 3) -> (H, W, C)
#
# Image after transformation:
# Transformed image type: torch.float32
# Transformed image shape: torch.Size([3, 224, 224]) -> (C, H, W)

# %%
# Plotting the original and transformed image
plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(img_array)
plt.axis('off')
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(transformed_img.permute(1, 2, 0))
plt.axis('off')
plt.title("Transformed Image")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Transformed Image')

# %%
import os

def remove_ds_store_files(root_dir):
    for root, dirs, files in os.walk(root_dir):
        for file in files:
            if file == '.DS_Store':
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f'Removed: {file_path}')

# Path to your dataset directory
dataset_dir = 'data/food-101/images'  # Update this path to your actual dataset directory

remove_ds_store_files(dataset_dir)
print('All .DS_Store files have been removed.')
# Out:
# All .DS_Store files have been removed.

# %% [markdown]
# ## 4. Loading the data into a Dataset

# %%
# Define the directories using Path for better cross-platform compatibility
base_dir = Path('data/food-101/images')
train_dir = base_dir / 'train'
test_dir = base_dir / 'test'

# Using ImageFolder to load the data
train_data = datasets.ImageFolder(str(train_dir), transform=train_transform)
test_data = datasets.ImageFolder(str(test_dir), transform=test_transform)

# Output to see what's loaded
print(f'Train data classes: {train_data.classes}')
print(f'Test data classes: {test_data.classes}')
# Out:
# Train data classes: ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheese_plate', 'cheesecake', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_soup', 'mussels', 'nachos', 'omelette', 'onion_rings', 'oysters', 'pad_thai', 'paella', 'pancakes', 'panna_cotta', 'peking_duck', 'pho', 'pizza', 'pork_chop', 'poutine', 'prime_rib', 'pulled_pork_sandwich', 'ramen', 'ravioli', 'red_velvet_cake', 'risotto', 'samosa', 'sashimi', 'scallops', 'seaweed_salad', 'shrimp_and_grits', 'spaghetti_bolognese', 'spaghetti_carbonara', 'spring_rolls', 'steak', 'strawberry_shortcake', 'sushi', 'tacos', 'takoyaki', 'tiramisu', 'tuna_tartare', 'waffles']
# Test data classes: ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheese_plate', 'cheesecake', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_soup', 'mussels', 'nachos', 'omelette', 'onion_rings', 'oysters', 'pad_thai', 'paella', 'pancakes', 'panna_cotta', 'peking_duck', 'pho', 'pizza', 'pork_chop', 'poutine', 'prime_rib', 'pulled_pork_sandwich', 'ramen', 'ravioli', 'red_velvet_cake', 'risotto', 'samosa', 'sashimi', 'scallops', 'seaweed_salad', 'shrimp_and_grits', 'spaghetti_bolognese', 'spaghetti_carbonara', 'spring_rolls', 'steak', 'strawberry_shortcake', 'sushi', 'tacos', 'takoyaki', 'tiramisu', 'tuna_tartare', 'waffles']

# %%
# Getting class names as a list
class_names = train_data.classes

# Getting class names as a dict
class_names_dict = train_data.class_to_idx

class_names, class_names_dict
# Out:
# (['apple_pie',
#   'baby_back_ribs',
#   'baklava',
#   'beef_carpaccio',
#   'beef_tartare',
#   'beet_salad',
#   'beignets',
#   'bibimbap',
#   'bread_pudding',
#   'breakfast_burrito',
#   'bruschetta',
#   'caesar_salad',
#   'cannoli',
#   'caprese_salad',
#   'carrot_cake',
#   'ceviche',
#   'cheese_plate',
#   'cheesecake',
#   'chicken_curry',
#   'chicken_quesadilla',
#   'chicken_wings',
#   'chocolate_cake',
#   'chocolate_mousse',
#   'churros',
#   'clam_chowder',
#   'club_sandwich',
#   'crab_cakes',
#   'creme_brulee',
#   'croque_madame',
#   'cup_cakes',
#   'deviled_eggs',
#   'donuts',
#   'dumplings',
#   'edamame',
#   'eggs_benedict',
#   'escargots',
#   'falafel',
#   'filet_mignon',
#   'fish_and_chips',
#   'foie_gras',
#   'french_fries',
#   'french_onion_soup',
#   'french_toast',
#   'fried_calamari',
#   'fried_rice',
#   'frozen_yogurt',
#   'garlic_bread',
#   'gnocchi',
#   'greek_salad',
#   'grilled_cheese_sandwich',
#   'grilled_salmon',
#   'guacamole',
#   'gyoza',
#   'hamburger',
#   'hot_and_sour_soup',
#   'hot_dog',
#   'huevos_rancheros',
#   'hummus',
#   'ice_cream',
#   'lasagna',
#   'lobster_bisque',
#   'lobster_roll_sandwich',
#   'macaroni_and_cheese',
#   'macarons',
#   'miso_soup',
#   'mussels',
#   'nachos',
#   'omelette',
#   'onion_rings',
#   'oysters',
#   'pad_thai',
#   'paella',
#   'pancakes',
#   'panna_cotta',
#   'peking_duck',
#   'pho',
#   'pizza',
#   'pork_chop',
#   'poutine',
#   'prime_rib',
#   'pulled_pork_sandwich',
#   'ramen',
#   'ravioli',
#   'red_velvet_cake',
#   'risotto',
#   'samosa',
#   'sashimi',
#   'scallops',
#   'seaweed_salad',
#   'shrimp_and_grits',
#   'spaghetti_bolognese',
#   'spaghetti_carbonara',
#   'spring_rolls',
#   'steak',
#   'strawberry_shortcake',
#   'sushi',
#   'tacos',
#   'takoyaki',
#   'tiramisu',
#   'tuna_tartare',
#   'waffles'],
#  {'apple_pie': 0,
#   'baby_back_ribs': 1,
#   'baklava': 2,
#   'beef_carpaccio': 3,
#   'beef_tartare': 4,
#   'beet_salad': 5,
#   'beignets': 6,
#   'bibimbap': 7,
#   'bread_pudding': 8,
#   'breakfast_burrito': 9,
#   'bruschetta': 10,
#   'caesar_salad': 11,
#   'cannoli': 12,
#   'caprese_salad': 13,
#   'carrot_cake': 14,
#   'ceviche': 15,
#   'cheese_plate': 16,
#   'cheesecake': 17,
#   'chicken_curry': 18,
#   'chicken_quesadilla': 19,
#   'chicken_wings': 20,
#   'chocolate_cake': 21,
#   'chocolate_mousse': 22,
#   'churros': 23,
#   'clam_chowder': 24,
#   'club_sandwich': 25,
#   'crab_cakes': 26,
#   'creme_brulee': 27,
#   'croque_madame': 28,
#   'cup_cakes': 29,
#   'deviled_eggs': 30,
#   'donuts': 31,
#   'dumplings': 32,
#   'edamame': 33,
#   'eggs_benedict': 34,
#   'escargots': 35,
#   'falafel': 36,
#   'filet_mignon': 37,
#   'fish_and_chips': 38,
#   'foie_gras': 39,
#   'french_fries': 40,
#   'french_onion_soup': 41,
#   'french_toast': 42,
#   'fried_calamari': 43,
#   'fried_rice': 44,
#   'frozen_yogurt': 45,
#   'garlic_bread': 46,
#   'gnocchi': 47,
#   'greek_salad': 48,
#   'grilled_cheese_sandwich': 49,
#   'grilled_salmon': 50,
#   'guacamole': 51,
#   'gyoza': 52,
#   'hamburger': 53,
#   'hot_and_sour_soup': 54,
#   'hot_dog': 55,
#   'huevos_rancheros': 56,
#   'hummus': 57,
#   'ice_cream': 58,
#   'lasagna': 59,
#   'lobster_bisque': 60,
#   'lobster_roll_sandwich': 61,
#   'macaroni_and_cheese': 62,
#   'macarons': 63,
#   'miso_soup': 64,
#   'mussels': 65,
#   'nachos': 66,
#   'omelette': 67,
#   'onion_rings': 68,
#   'oysters': 69,
#   'pad_thai': 70,
#   'paella': 71,
#   'pancakes': 72,
#   'panna_cotta': 73,
#   'peking_duck': 74,
#   'pho': 75,
#   'pizza': 76,
#   'pork_chop': 77,
#   'poutine': 78,
#   'prime_rib': 79,
#   'pulled_pork_sandwich': 80,
#   'ramen': 81,
#   'ravioli': 82,
#   'red_velvet_cake': 83,
#   'risotto': 84,
#   'samosa': 85,
#   'sashimi': 86,
#   'scallops': 87,
#   'seaweed_salad': 88,
#   'shrimp_and_grits': 89,
#   'spaghetti_bolognese': 90,
#   'spaghetti_carbonara': 91,
#   'spring_rolls': 92,
#   'steak': 93,
#   'strawberry_shortcake': 94,
#   'sushi': 95,
#   'tacos': 96,
#   'takoyaki': 97,
#   'tiramisu': 98,
#   'tuna_tartare': 99,
#   'waffles': 100})

# %%
# Checking length of the train and test data
len(train_data), len(test_data)
# Out:
# (75750, 25250)

# %% [markdown]
# ## 5. Creating Dataloader

# %%
# Setting batch size
BATCH_SIZE = 128

# Setting up the dataloaders
NUM_WORKERS = os.cpu_count()

# Setting up the dataloaders
train_loader = DataLoader(train_data,
                          batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS,
                          pin_memory=True) # Set to True if using GPU. It provides faster data transfer to CUDA-enabled GPUs

test_loader = DataLoader(test_data,
                            batch_size=BATCH_SIZE, shuffle=False,
                            num_workers=NUM_WORKERS,
                            pin_memory=True)

len(train_loader), len(test_loader)
# Out:
# (592, 198)

# %%
# Getting the first batch of data
img, label = next(iter(train_loader))

# Checking the shape of the image and label
print(f"Image batch shape: {img.shape} -> (B, C, H, W)")
print(f"Label batch shape: {label.shape} -> (B)")
# Out:
# Image batch shape: torch.Size([128, 3, 224, 224]) -> (B, C, H, W)
# Label batch shape: torch.Size([128]) -> (B)

# %% [markdown]
# ## 6. Creating the model

# %%
# Loading the pretrained model
weights = models.DenseNet201_Weights.IMAGENET1K_V1

# model = models.DenseNet(weights= weights)
model = models.densenet201(weights= weights)

# %%
# Freezing parameters to avoid backdrop
for param in model.parameters():
    param.requires_grad = False

# %%
checkpoint_path = "./classifier/food_classifier.pt"
classifier = nn.Sequential(
    nn.Linear(1920, 1024),
    nn.LeakyReLU(),
    nn.Linear(1024, 101),
)

model.classifier = classifier
model.load_state_dict(torch.load(checkpoint_path, map_location='cpu'), strict= False)
model.to(device)

summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# DenseNet                                 --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       (9,408)
# │    └─BatchNorm2d: 2-2                  (128)
# │    └─ReLU: 2-3                         --
# │    └─MaxPool2d: 2-4                    --
# │    └─_DenseBlock: 2-5                  --
# │    │    └─_DenseLayer: 3-1             (45,440)
# │    │    └─_DenseLayer: 3-2             (49,600)
# │    │    └─_DenseLayer: 3-3             (53,760)
# │    │    └─_DenseLayer: 3-4             (57,920)
# │    │    └─_DenseLayer: 3-5             (62,080)
# │    │    └─_DenseLayer: 3-6             (66,240)
# │    └─_Transition: 2-6                  --
# │    │    └─BatchNorm2d: 3-7             (512)
# │    │    └─ReLU: 3-8                    --
# │    │    └─Conv2d: 3-9                  (32,768)
# │    │    └─AvgPool2d: 3-10              --
# │    └─_DenseBlock: 2-7                  --
# │    │    └─_DenseLayer: 3-11            (53,760)
# │    │    └─_DenseLayer: 3-12            (57,920)
# │    │    └─_DenseLayer: 3-13            (62,080)
# │    │    └─_DenseLayer: 3-14            (66,240)
# │    │    └─_DenseLayer: 3-15            (70,400)
# │    │    └─_DenseLayer: 3-16            (74,560)
# │    │    └─_DenseLayer: 3-17            (78,720)
# │    │    └─_DenseLayer: 3-18            (82,880)
# │    │    └─_DenseLayer: 3-19            (87,040)
# │    │    └─_DenseLayer: 3-20            (91,200)
# │    │    └─_DenseLayer: 3-21            (95,360)
# │    │    └─_DenseLayer: 3-22            (99,520)
# │    └─_Transition: 2-8                  --
# │    │    └─BatchNorm2d: 3-23            (1,024)
# │    │    └─ReLU: 3-24                   --
# │    │    └─Conv2d: 3-25                 (131,072)
# │    │    └─AvgPool2d: 3-26              --
# │    └─_DenseBlock: 2-9                  --
# │    │    └─_DenseLayer: 3-27            (70,400)
# │    │    └─_DenseLayer: 3-28            (74,560)
# │    │    └─_DenseLayer: 3-29            (78,720)
# │    │    └─_DenseLayer: 3-30            (82,880)
# │    │    └─_DenseLayer: 3-31            (87,040)
# │    │    └─_DenseLayer: 3-32            (91,200)
# │    │    └─_DenseLayer: 3-33            (95,360)
# │    │    └─_DenseLayer: 3-34            (99,520)
# │    │    └─_DenseLayer: 3-35            (103,680)
# │    │    └─_DenseLayer: 3-36            (107,840)
# │    │    └─_DenseLayer: 3-37            (112,000)
# │    │    └─_DenseLayer: 3-38            (116,160)
# │    │    └─_DenseLayer: 3-39            (120,320)
# │    │    └─_DenseLayer: 3-40            (124,480)
# │    │    └─_DenseLayer: 3-41            (128,640)
# │    │    └─_DenseLayer: 3-42            (132,800)
# │    │    └─_DenseLayer: 3-43            (136,960)
# │    │    └─_DenseLayer: 3-44            (141,120)
# │    │    └─_DenseLayer: 3-45            (145,280)
# │    │    └─_DenseLayer: 3-46            (149,440)
# │    │    └─_DenseLayer: 3-47            (153,600)
# │    │    └─_DenseLayer: 3-48            (157,760)
# │    │    └─_DenseLayer: 3-49            (161,920)
# │    │    └─_DenseLayer: 3-50            (166,080)
# │    │    └─_DenseLayer: 3-51            (170,240)
# │    │    └─_DenseLayer: 3-52            (174,400)
# │    │    └─_DenseLayer: 3-53            (178,560)
# │    │    └─_DenseLayer: 3-54            (182,720)
# │    │    └─_DenseLayer: 3-55            (186,880)
# │    │    └─_DenseLayer: 3-56            (191,040)
# │    │    └─_DenseLayer: 3-57            (195,200)
# │    │    └─_DenseLayer: 3-58            (199,360)
# │    │    └─_DenseLayer: 3-59            (203,520)
# │    │    └─_DenseLayer: 3-60            (207,680)
# │    │    └─_DenseLayer: 3-61            (211,840)
# │    │    └─_DenseLayer: 3-62            (216,000)
# │    │    └─_DenseLayer: 3-63            (220,160)
# │    │    └─_DenseLayer: 3-64            (224,320)
# │    │    └─_DenseLayer: 3-65            (228,480)
# │    │    └─_DenseLayer: 3-66            (232,640)
# │    │    └─_DenseLayer: 3-67            (236,800)
# │    │    └─_DenseLayer: 3-68            (240,960)
# │    │    └─_DenseLayer: 3-69            (245,120)
# │    │    └─_DenseLayer: 3-70            (249,280)
# │    │    └─_DenseLayer: 3-71            (253,440)
# │    │    └─_DenseLayer: 3-72            (257,600)
# │    │    └─_DenseLayer: 3-73            (261,760)
# │    │    └─_DenseLayer: 3-74            (265,920)
# │    └─_Transition: 2-10                 --
# │    │    └─BatchNorm2d: 3-75            (3,584)
# │    │    └─ReLU: 3-76                   --
# │    │    └─Conv2d: 3-77                 (1,605,632)
# │    │    └─AvgPool2d: 3-78              --
# │    └─_DenseBlock: 2-11                 --
# │    │    └─_DenseLayer: 3-79            (153,600)
# │    │    └─_DenseLayer: 3-80            (157,760)
# │    │    └─_DenseLayer: 3-81            (161,920)
# │    │    └─_DenseLayer: 3-82            (166,080)
# │    │    └─_DenseLayer: 3-83            (170,240)
# │    │    └─_DenseLayer: 3-84            (174,400)
# │    │    └─_DenseLayer: 3-85            (178,560)
# │    │    └─_DenseLayer: 3-86            (182,720)
# │    │    └─_DenseLayer: 3-87            (186,880)
# │    │    └─_DenseLayer: 3-88            (191,040)
# │    │    └─_DenseLayer: 3-89            (195,200)
# │    │    └─_DenseLayer: 3-90            (199,360)
# │    │    └─_DenseLayer: 3-91            (203,520)
# │    │    └─_DenseLayer: 3-92            (207,680)
# │    │    └─_DenseLayer: 3-93            (211,840)
# │    │    └─_DenseLayer: 3-94            (216,000)
# │    │    └─_DenseLayer: 3-95            (220,160)
# │    │    └─_DenseLayer: 3-96            (224,320)
# │    │    └─_DenseLayer: 3-97            (228,480)
# │    │    └─_DenseLayer: 3-98            (232,640)
# │    │    └─_DenseLayer: 3-99            (236,800)
# │    │    └─_DenseLayer: 3-100           (240,960)
# │    │    └─_DenseLayer: 3-101           (245,120)
# │    │    └─_DenseLayer: 3-102           (249,280)
# │    │    └─_DenseLayer: 3-103           (253,440)
# │    │    └─_DenseLayer: 3-104           (257,600)
# │    │    └─_DenseLayer: 3-105           (261,760)
# │    │    └─_DenseLayer: 3-106           (265,920)
# │    │    └─_DenseLayer: 3-107           (270,080)
# │    │    └─_DenseLayer: 3-108           (274,240)
# │    │    └─_DenseLayer: 3-109           (278,400)
# │    │    └─_DenseLayer: 3-110           (282,560)
# │    └─BatchNorm2d: 2-12                 (3,840)
# ├─Sequential: 1-2                        --
# │    └─Linear: 2-13                      1,967,104
# │    └─LeakyReLU: 2-14                   --
# │    └─Linear: 2-15                      103,525
# =================================================================
# Total params: 20,163,557
# Trainable params: 2,070,629
# Non-trainable params: 18,092,928
# =================================================================

# %% [markdown]
# ## 7. Preparing the training loop

# %%
# Creating training function
def train_step(model : nn.Module,
               dataloader: DataLoader,
               loss_fn: nn.Module,
               optimizer: torch.optim.Optimizer,
               device: torch.device) -> Dict[str, float]:
    
    # Setting model to train mode
    model.train()

    # Starting accuracy and loss at 0
    train_loss, train_accuracy = 0.0, 0.0

    # Looping through the data
    for images, label in tqdm(dataloader):
        # Sending data to device
        images, label = images.to(device), label.to(device)

        # Forward pass
        output = model(images)

        # Calculating loss
        loss = loss_fn(output, label)
        train_loss += loss.item()

        # Zeroing the gradients
        optimizer.zero_grad()

        # Backward pass
        loss.backward()

        # Optimizing the parameters
        optimizer.step()

        # Calculate accuracy
        predictions = output.argmax(dim=1)
        train_accuracy += torch.sum(predictions == label).item() / len(predictions)

    # Adjusting metrics
    train_loss /= len(dataloader)
    train_accuracy /= len(dataloader)

    return {'train_loss': train_loss, 'train_accuracy': train_accuracy}

# %%
# Creating testing function
def testing_step(model: nn.Module,
                 dataloader: DataLoader,
                 loss_fn: nn.Module,
                 device: torch.device) -> Dict[str, float]:
    
    # Setting model to evaluation mode
    model.eval()

    # Starting accuracy and loss at 0
    test_loss, test_accuracy = 0.0, 0.0

    # Turning off gradient computation
    with torch.inference_mode():
        # Looping through the data
        for images, label in tqdm(dataloader):
            # Sending data to device
            images, label = images.to(device), label.to(device)

            # Forward pass
            outputs = model(images)

            # Calculating loss
            loss = loss_fn(outputs, label)
            test_loss += loss.item()

            # Calculating accuracy
            predictions = outputs.argmax(dim=1)
            test_accuracy += torch.sum(predictions == label).item() / len(predictions)

    # Adjusting metrics
    test_loss /= len(dataloader)
    test_accuracy /= len(dataloader)

    return {'test_loss': test_loss, 'test_accuracy': test_accuracy}

# %%
# Function to train the model
def training(model: nn.Module,
             train_loader: DataLoader,
             test_loader: DataLoader,
             loss_fn: nn.Module,
             optimizer: torch.optim.Optimizer,
             device: torch.device,
             epochs: int) -> Dict[str, list]:
    
    # Lists to store metrics
    results = {'train_loss': [], 'train_accuracy': [], 'test_loss': [], 'test_accuracy': []}

    # Loop through the epochs
    for epoch in tqdm(range(epochs)):
        # Training step
        train_results = train_step(model, train_loader, loss_fn, optimizer, device)

        # Testing step
        test_results = testing_step(model, test_loader, loss_fn, device)

        # Saving metrics
        results['train_loss'].append(train_results['train_loss'])
        results['train_accuracy'].append(train_results['train_accuracy'])
        results['test_loss'].append(test_results['test_loss'])
        results['test_accuracy'].append(test_results['test_accuracy'])

        print(f"Epoch: {epoch + 1}/{epochs} | "
              f"Train loss: {train_results['train_loss']:.4f} | "
              f"Train accuracy: {train_results['train_accuracy']:.4f} | "
              f"Test loss: {test_results['test_loss']:.4f} | "
              f"Test accuracy: {test_results['test_accuracy']:.4f}")
        
    return results

# %% [markdown]
# ## 8. Training the model

# %%
# Setting seeds for reproducibility
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Setting device again
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Setting the number of Epochs
EPOCHS = 5

# Setting the loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=[0.9, 0.999])

# Starting timer
from time import time
start_time = time()

# Training the model
model_results = training(model, train_loader, test_loader, loss_fn, optimizer, device, EPOCHS)

# Ending timer
end_time = time() 

# Calculating total time
total_time = end_time - start_time

# Printing total time3
print("Model has been successfully trained!")
print(f"Total training time: {total_time // 60:.0f} minutes and {total_time % 60:.0f} seconds on {device}")
print(f"Average time per epoch: {total_time / EPOCHS:.2f} seconds")
print("Training results: ", model_results)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/592 [00:00<?, ?it/s]
#   0%|          | 0/198 [00:00<?, ?it/s]
# Epoch: 1/5 | Train loss: 1.0983 | Train accuracy: 0.7156 | Test loss: 0.3132 | Test accuracy: 0.9066
#   0%|          | 0/592 [00:00<?, ?it/s]
#   0%|          | 0/198 [00:00<?, ?it/s]
# Epoch: 2/5 | Train loss: 1.0680 | Train accuracy: 0.7235 | Test loss: 0.2991 | Test accuracy: 0.9123
#   0%|          | 0/592 [00:00<?, ?it/s]
#   0%|          | 0/198 [00:00<?, ?it/s]
# Epoch: 3/5 | Train loss: 1.0618 | Train accuracy: 0.7233 | Test loss: 0.3088 | Test accuracy: 0.9098
#   0%|          | 0/592 [00:00<?, ?it/s]
#   0%|          | 0/198 [00:00<?, ?it/s]
# Epoch: 4/5 | Train loss: 1.0468 | Train accuracy: 0.7272 | Test loss: 0.3297 | Test accuracy: 0.9052
#   0%|          | 0/592 [00:00<?, ?it/s]
#   0%|          | 0/198 [00:00<?, ?it/s]
# Epoch: 5/5 | Train loss: 1.0373 | Train accuracy: 0.7303 | Test loss: 0.3012 | Test accuracy: 0.9117
# Model has been successfully trained!
# Total training time: 58 minutes and 7 seconds on cuda
# Average time per epoch: 697.46 seconds
# Training results:  {'train_loss': [1.0982872908179824, 1.06802524424888, 1.0618116886833229, 1.046777121118597, 1.0373032803873758], 'train_accuracy': [0.7155711260433227, 0.7235052435247749, 0.7233274749933758, 0.7271506628411499, 0.7302550137453631], 'test_loss': [0.3131749051637157, 0.299060395174434, 0.30876059311376225, 0.3296830452670816, 0.3011526734959684], 'test_accuracy': [0.9066445707070707, 0.9123356729055259, 0.9097709633095662, 0.9051846590909091, 0.9117043597742127]}

# %% [markdown]
# ## 9. Evaluating model

# %%
# Function to plot the loss curve
def plot_loss_curve(results: Dict[str, list]) -> None:
    plt.figure(figsize=(10, 6))
    plt.plot(results['train_loss'], label='Train Loss', marker='o')
    plt.plot(results['test_loss'], label='Test Loss', marker='o')
    plt.title('Loss Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# Plotting the loss curve
plot_loss_curve(model_results)

# %% [markdown]
# ## 10. Plotting a batch of images with their predictions

# %%
# Function to plot a random batch of images
def plot_random_batch(model : nn.Module, dataloader: DataLoader, class_names: List[str]) -> None:
    # Setting model to evaluation mode
    model.eval()

    # Getting a random batch of data
    images, labels = random.choice(list(iter(dataloader)))

    # Sending data to device
    images, labels = images.to('cpu'), labels.to('cpu')

    # Getting predictions
    outputs = model(images)

    # Getting predicted labels
    predictions = outputs.argmax(dim=1)

    # Plotting the images
    plt.figure(figsize=(16, 16))
    for i in range(16):
        plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].permute(1, 2, 0).cpu())
        color = 'green' if predictions[i] == labels[i] else 'red'
        plt.axis(False)
        plt.title(f"Actual: {class_names[labels[i]]} | Predicted: {class_names[predictions[i]]}", color=color)
    plt.show()

# %%
plot_random_batch(model, test_loader, class_names)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 plot_random_batch(model, test_loader, class_names)
#
# Cell In[34], line 7, in plot_random_batch(model, dataloader, class_names)
#       4 model.eval()
#       6 # Getting a random batch of data
# ----> 7 images, labels = random.choice(list(iter(dataloader)))
#       9 # Sending data to device
#      10 images, labels = images.to('cpu'), labels.to('cpu')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\utils\data\dataloader.py:1346, in _MultiProcessingDataLoaderIter._next_data(self)
#    1344 else:
#    1345     del self._task_info[idx]
# -> 1346     return self._process_data(data)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\utils\data\dataloader.py:1372, in _MultiProcessingDataLoaderIter._process_data(self, data)
#    1370 self._try_put_index()
#    1371 if isinstance(data, ExceptionWrapper):
# -> 1372     data.reraise()
#    1373 return data
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_utils.py:705, in ExceptionWrapper.reraise(self)
#     701 except TypeError:
#     702     # If the exception takes multiple arguments, don't try to
#     703     # instantiate since we don't know how to
#     704     raise RuntimeError(msg) from None
# --> 705 raise exception
#
# RuntimeError: Caught RuntimeError in pin memory thread for device 0.
# Original Traceback (most recent call last):
#   File "C:\Users\951550731\AppData\Roaming\Python\Python39\site-packages\torch\utils\data\_utils\pin_memory.py", line 37, in do_one_step
#     data = pin_memory(data, device)
#   File "C:\Users\951550731\AppData\Roaming\Python\Python39\site-packages\torch\utils\data\_utils\pin_memory.py", line 88, in pin_memory
#     clone[i] = pin_memory(item, device)
#   File "C:\Users\951550731\AppData\Roaming\Python\Python39\site-packages\torch\utils\data\_utils\pin_memory.py", line 58, in pin_memory
#     return data.pin_memory(device)
# RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# ## 10. Saving and loading the model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
# Creating directory to savel the model
MODEL_PATH = Path('models')
MODEL_PATH.mkdir(exist_ok=True)

# Saving the model
# torch.save(model.state_dict(), MODEL_PATH/'food101-inception-model.pth')

# %%
# Load the saved model and label encoder
model = models.densenet201(weights=None)
classifier = nn.Sequential(
    nn.Linear(1920, 1024),
    nn.LeakyReLU(),
    nn.Linear(1024, 101),
)
model.classifier = classifier
model.load_state_dict(torch.load(MODEL_PATH/'food101-inception-model.pth', map_location='cpu'))
model.to("cpu")
summary(model, input_size=(32, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DenseNet                                 [32, 101]                 --
# ├─Sequential: 1-1                        [32, 1920, 7, 7]          --
# │    └─Conv2d: 2-1                       [32, 64, 112, 112]        9,408
# │    └─BatchNorm2d: 2-2                  [32, 64, 112, 112]        128
# │    └─ReLU: 2-3                         [32, 64, 112, 112]        --
# │    └─MaxPool2d: 2-4                    [32, 64, 56, 56]          --
# │    └─_DenseBlock: 2-5                  [32, 256, 56, 56]         --
# │    │    └─_DenseLayer: 3-1             [32, 32, 56, 56]          45,440
# │    │    └─_DenseLayer: 3-2             [32, 32, 56, 56]          49,600
# │    │    └─_DenseLayer: 3-3             [32, 32, 56, 56]          53,760
# │    │    └─_DenseLayer: 3-4             [32, 32, 56, 56]          57,920
# │    │    └─_DenseLayer: 3-5             [32, 32, 56, 56]          62,080
# │    │    └─_DenseLayer: 3-6             [32, 32, 56, 56]          66,240
# │    └─_Transition: 2-6                  [32, 128, 28, 28]         --
# │    │    └─BatchNorm2d: 3-7             [32, 256, 56, 56]         512
# │    │    └─ReLU: 3-8                    [32, 256, 56, 56]         --
# │    │    └─Conv2d: 3-9                  [32, 128, 56, 56]         32,768
# │    │    └─AvgPool2d: 3-10              [32, 128, 28, 28]         --
# │    └─_DenseBlock: 2-7                  [32, 512, 28, 28]         --
# │    │    └─_DenseLayer: 3-11            [32, 32, 28, 28]          53,760
# │    │    └─_DenseLayer: 3-12            [32, 32, 28, 28]          57,920
# │    │    └─_DenseLayer: 3-13            [32, 32, 28, 28]          62,080
# │    │    └─_DenseLayer: 3-14            [32, 32, 28, 28]          66,240
# │    │    └─_DenseLayer: 3-15            [32, 32, 28, 28]          70,400
# │    │    └─_DenseLayer: 3-16            [32, 32, 28, 28]          74,560
# │    │    └─_DenseLayer: 3-17            [32, 32, 28, 28]          78,720
# │    │    └─_DenseLayer: 3-18            [32, 32, 28, 28]          82,880
# │    │    └─_DenseLayer: 3-19            [32, 32, 28, 28]          87,040
# │    │    └─_DenseLayer: 3-20            [32, 32, 28, 28]          91,200
# │    │    └─_DenseLayer: 3-21            [32, 32, 28, 28]          95,360
# │    │    └─_DenseLayer: 3-22            [32, 32, 28, 28]          99,520
# │    └─_Transition: 2-8                  [32, 256, 14, 14]         --
# │    │    └─BatchNorm2d: 3-23            [32, 512, 28, 28]         1,024
# │    │    └─ReLU: 3-24                   [32, 512, 28, 28]         --
# │    │    └─Conv2d: 3-25                 [32, 256, 28, 28]         131,072
# │    │    └─AvgPool2d: 3-26              [32, 256, 14, 14]         --
# │    └─_DenseBlock: 2-9                  [32, 1792, 14, 14]        --
# │    │    └─_DenseLayer: 3-27            [32, 32, 14, 14]          70,400
# │    │    └─_DenseLayer: 3-28            [32, 32, 14, 14]          74,560
# │    │    └─_DenseLayer: 3-29            [32, 32, 14, 14]          78,720
# │    │    └─_DenseLayer: 3-30            [32, 32, 14, 14]          82,880
# │    │    └─_DenseLayer: 3-31            [32, 32, 14, 14]          87,040
# │    │    └─_DenseLayer: 3-32            [32, 32, 14, 14]          91,200
# │    │    └─_DenseLayer: 3-33            [32, 32, 14, 14]          95,360
# │    │    └─_DenseLayer: 3-34            [32, 32, 14, 14]          99,520
# │    │    └─_DenseLayer: 3-35            [32, 32, 14, 14]          103,680
# │    │    └─_DenseLayer: 3-36            [32, 32, 14, 14]          107,840
# │    │    └─_DenseLayer: 3-37            [32, 32, 14, 14]          112,000
# │    │    └─_DenseLayer: 3-38            [32, 32, 14, 14]          116,160
# │    │    └─_DenseLayer: 3-39            [32, 32, 14, 14]          120,320
# │    │    └─_DenseLayer: 3-40            [32, 32, 14, 14]          124,480
# │    │    └─_DenseLayer: 3-41            [32, 32, 14, 14]          128,640
# │    │    └─_DenseLayer: 3-42            [32, 32, 14, 14]          132,800
# │    │    └─_DenseLayer: 3-43            [32, 32, 14, 14]          136,960
# │    │    └─_DenseLayer: 3-44            [32, 32, 14, 14]          141,120
# │    │    └─_DenseLayer: 3-45            [32, 32, 14, 14]          145,280
# │    │    └─_DenseLayer: 3-46            [32, 32, 14, 14]          149,440
# │    │    └─_DenseLayer: 3-47            [32, 32, 14, 14]          153,600
# │    │    └─_DenseLayer: 3-48            [32, 32, 14, 14]          157,760
# │    │    └─_DenseLayer: 3-49            [32, 32, 14, 14]          161,920
# │    │    └─_DenseLayer: 3-50            [32, 32, 14, 14]          166,080
# │    │    └─_DenseLayer: 3-51            [32, 32, 14, 14]          170,240
# │    │    └─_DenseLayer: 3-52            [32, 32, 14, 14]          174,400
# │    │    └─_DenseLayer: 3-53            [32, 32, 14, 14]          178,560
# │    │    └─_DenseLayer: 3-54            [32, 32, 14, 14]          182,720
# │    │    └─_DenseLayer: 3-55            [32, 32, 14, 14]          186,880
# │    │    └─_DenseLayer: 3-56            [32, 32, 14, 14]          191,040
# │    │    └─_DenseLayer: 3-57            [32, 32, 14, 14]          195,200
# │    │    └─_DenseLayer: 3-58            [32, 32, 14, 14]          199,360
# │    │    └─_DenseLayer: 3-59            [32, 32, 14, 14]          203,520
# │    │    └─_DenseLayer: 3-60            [32, 32, 14, 14]          207,680
# │    │    └─_DenseLayer: 3-61            [32, 32, 14, 14]          211,840
# │    │    └─_DenseLayer: 3-62            [32, 32, 14, 14]          216,000
# │    │    └─_DenseLayer: 3-63            [32, 32, 14, 14]          220,160
# │    │    └─_DenseLayer: 3-64            [32, 32, 14, 14]          224,320
# │    │    └─_DenseLayer: 3-65            [32, 32, 14, 14]          228,480
# │    │    └─_DenseLayer: 3-66            [32, 32, 14, 14]          232,640
# │    │    └─_DenseLayer: 3-67            [32, 32, 14, 14]          236,800
# │    │    └─_DenseLayer: 3-68            [32, 32, 14, 14]          240,960
# │    │    └─_DenseLayer: 3-69            [32, 32, 14, 14]          245,120
# │    │    └─_DenseLayer: 3-70            [32, 32, 14, 14]          249,280
# │    │    └─_DenseLayer: 3-71            [32, 32, 14, 14]          253,440
# │    │    └─_DenseLayer: 3-72            [32, 32, 14, 14]          257,600
# │    │    └─_DenseLayer: 3-73            [32, 32, 14, 14]          261,760
# │    │    └─_DenseLayer: 3-74            [32, 32, 14, 14]          265,920
# │    └─_Transition: 2-10                 [32, 896, 7, 7]           --
# │    │    └─BatchNorm2d: 3-75            [32, 1792, 14, 14]        3,584
# │    │    └─ReLU: 3-76                   [32, 1792, 14, 14]        --
# │    │    └─Conv2d: 3-77                 [32, 896, 14, 14]         1,605,632
# │    │    └─AvgPool2d: 3-78              [32, 896, 7, 7]           --
# │    └─_DenseBlock: 2-11                 [32, 1920, 7, 7]          --
# │    │    └─_DenseLayer: 3-79            [32, 32, 7, 7]            153,600
# │    │    └─_DenseLayer: 3-80            [32, 32, 7, 7]            157,760
# │    │    └─_DenseLayer: 3-81            [32, 32, 7, 7]            161,920
# │    │    └─_DenseLayer: 3-82            [32, 32, 7, 7]            166,080
# │    │    └─_DenseLayer: 3-83            [32, 32, 7, 7]            170,240
# │    │    └─_DenseLayer: 3-84            [32, 32, 7, 7]            174,400
# │    │    └─_DenseLayer: 3-85            [32, 32, 7, 7]            178,560
# │    │    └─_DenseLayer: 3-86            [32, 32, 7, 7]            182,720
# │    │    └─_DenseLayer: 3-87            [32, 32, 7, 7]            186,880
# │    │    └─_DenseLayer: 3-88            [32, 32, 7, 7]            191,040
# │    │    └─_DenseLayer: 3-89            [32, 32, 7, 7]            195,200
# │    │    └─_DenseLayer: 3-90            [32, 32, 7, 7]            199,360
# │    │    └─_DenseLayer: 3-91            [32, 32, 7, 7]            203,520
# │    │    └─_DenseLayer: 3-92            [32, 32, 7, 7]            207,680
# │    │    └─_DenseLayer: 3-93            [32, 32, 7, 7]            211,840
# │    │    └─_DenseLayer: 3-94            [32, 32, 7, 7]            216,000
# │    │    └─_DenseLayer: 3-95            [32, 32, 7, 7]            220,160
# │    │    └─_DenseLayer: 3-96            [32, 32, 7, 7]            224,320
# │    │    └─_DenseLayer: 3-97            [32, 32, 7, 7]            228,480
# │    │    └─_DenseLayer: 3-98            [32, 32, 7, 7]            232,640
# │    │    └─_DenseLayer: 3-99            [32, 32, 7, 7]            236,800
# │    │    └─_DenseLayer: 3-100           [32, 32, 7, 7]            240,960
# │    │    └─_DenseLayer: 3-101           [32, 32, 7, 7]            245,120
# │    │    └─_DenseLayer: 3-102           [32, 32, 7, 7]            249,280
# │    │    └─_DenseLayer: 3-103           [32, 32, 7, 7]            253,440
# │    │    └─_DenseLayer: 3-104           [32, 32, 7, 7]            257,600
# │    │    └─_DenseLayer: 3-105           [32, 32, 7, 7]            261,760
# │    │    └─_DenseLayer: 3-106           [32, 32, 7, 7]            265,920
# │    │    └─_DenseLayer: 3-107           [32, 32, 7, 7]            270,080
# │    │    └─_DenseLayer: 3-108           [32, 32, 7, 7]            274,240
# │    │    └─_DenseLayer: 3-109           [32, 32, 7, 7]            278,400
# │    │    └─_DenseLayer: 3-110           [32, 32, 7, 7]            282,560
# │    └─BatchNorm2d: 2-12                 [32, 1920, 7, 7]          3,840
# ├─Sequential: 1-2                        [32, 101]                 --
# │    └─Linear: 2-13                      [32, 1024]                1,967,104
# │    └─LeakyReLU: 2-14                   [32, 1024]                --
# │    └─Linear: 2-15                      [32, 101]                 103,525
# ==========================================================================================
# Total params: 20,163,557
# Trainable params: 20,163,557
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 137.34
# ==========================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 8335.12
# Params size (MB): 80.65
# Estimated Total Size (MB): 8435.05
# ==========================================================================================

# %% [markdown]
# ## Plotting a batch of images with their predictions

# %%
# Function to plot a random batch of images
def plot_random_batch(model : nn.Module, dataloader: DataLoader, class_names: List[str]) -> None:
    # Setting model to evaluation
    model.to("cpu")
    model.eval()
    images, labels = random.choice(list(iter(dataloader)))
    outputs = model(images.to("cpu"))
    predictions = outputs.argmax(dim=1)
    plt.figure(figsize=(16, 16))
    for i in range(16):
        plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].permute(1, 2, 0))
        color = 'green' if predictions[i] == labels[i] else 'red'
        plt.axis(False)
        plt.title(f"Actual: {class_names[labels[i]]} | Predicted: {class_names[predictions[i]]}", color=color)
    plt.show()

# %%
# Getting smaller batch size
BATCH_SIZE = 16
NUM_WORKERS = os.cpu_count()

# Setting up the new test dataloader
test_loader = DataLoader(test_data,
                         batch_size=BATCH_SIZE, shuffle=False,
                         num_workers=NUM_WORKERS)

# %%
plot_random_batch(model, test_loader, class_names)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plot_random_batch(model, test_loader, class_names)
#
# Cell In[14], line 6, in plot_random_batch(model, dataloader, class_names)
#       4 model.to("cpu")
#       5 model.eval()
# ----> 6 images, labels = random.choice(list(iter(dataloader)))
#       7 outputs = model(images.to("cpu"))
#       8 predictions = outputs.argmax(dim=1)
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1329, in _MultiProcessingDataLoaderIter._next_data(self)
#    1326     return self._process_data(data)
#    1328 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329 idx, data = self._get_data()
#    1330 self._tasks_outstanding -= 1
#    1331 if self._dataset_kind == _DatasetKind.Iterable:
#    1332     # Check for _IterableDatasetStopIteration
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1295, in _MultiProcessingDataLoaderIter._get_data(self)
#    1291     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1292     # need to call `.task_done()` because we don't use `.join()`.
#    1293 else:
#    1294     while True:
# -> 1295         success, data = self._try_get_data()
#    1296         if success:
#    1297             return data
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1120 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1121     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1122     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1130     # Returns a 2-tuple:
#    1131     #   (bool: whether successfully get data, any: data if successful else None)
#    1132     try:
# -> 1133         data = self._data_queue.get(timeout=timeout)
#    1134         return (True, data)
#    1135     except Exception as e:
#    1136         # At timeout and error, we manually check whether any worker has
#    1137         # failed. Note that this is the only mechanism for Windows to detect
#    1138         # worker failures.
#
# File /usr/lib/python3.12/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File /usr/lib/python3.12/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File /usr/lib/python3.12/multiprocessing/connection.py:440, in Connection._poll(self, timeout)
#     439 def _poll(self, timeout):
# --> 440     r = wait([self], timeout)
#     441     return bool(r)
#
# File /usr/lib/python3.12/multiprocessing/connection.py:1136, in wait(object_list, timeout)
#    1133     deadline = time.monotonic() + timeout
#    1135 while True:
# -> 1136     ready = selector.select(timeout)
#    1137     if ready:
#    1138         return [key.fileobj for (key, events) in ready]
#
# File /usr/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
# Function to predict the class of an image
import torchvision.transforms.functional as TF

def pred_and_plot_image(model: nn.Module,
                        image_path: str,
                        device: str,
                        class_names: List[str],
                        transform=None) -> None:
    # Carrega a imagem como PIL Image
    target_image = Image.open(image_path)

    # Aplica as transformações
    if transform:
        target_image = transform(target_image)
    else:
        # Converta para tensor e normalize aqui se nenhuma transformação foi fornecida
        target_image = TF.to_tensor(target_image)
        target_image = TF.normalize(target_image, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])

    # Certifica que a imagem e o modelo estão no mesmo dispositivo
    model.to(device)
    target_image = target_image.to(device)

    model.eval()
    with torch.inference_mode():
        # Adiciona a dimensão de lote
        target_image = target_image.unsqueeze(0)

        # Forward pass
        target_image_preds = model(target_image)

        # Converta logits para probabilidades
        target_image_probs = nn.functional.softmax(target_image_preds, dim=1)

        # Pega a classe com maior probabilidade
        target_image_preds_argmax = target_image_preds.argmax().cpu()

        # Plota a imagem
        plt.imshow(target_image[0].permute(1, 2, 0).cpu())
        if class_names:
            plt.title(f"Prediction: {class_names[target_image_preds_argmax]} | Probability: {target_image_probs.max().item():.3f}")
        else:
            plt.title(f"Prediction: {target_image_preds_argmax.cpu()} | Probability: {target_image_probs.max().item():.3f}")

        plt.axis(False)
        plt.show()

# Agora a função está ajustada para trabalhar com a imagem como PIL Image e depois convertê-la para tensor dentro da condição de transformação.

# %%
custom_image_path = 'data/pizza.jpeg'
simple_transform = transforms.Compose([transforms.Resize((224, 224)),
                                        transforms.ToTensor()])
pred_and_plot_image(model, custom_image_path, device, class_names, simple_transform)
